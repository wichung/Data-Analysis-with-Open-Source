# %% [markdown]
# <a href="https://colab.research.google.com/github/wichung/Data-Analysis-with-Open-Source/blob/main/%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_5%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오픈소스 기반 데이터 분석 5강 - 데이터 저장

# %% [markdown]
# ## 5-1 CSV 형식 저장

# %%
import pandas as pd

data = {
    'student_id': [101, 102, 103, 104, 105],
    'database_score': [85, 76, 92, 63, 88],
    'cloudcomputing_score': [78, 82, 95, 70, 84],
    'python_score': [92, 78, 85, 75, 91],
    'watch_rate': [0.95, 0.87, 0.99, 0.80, 0.93]
}
## DataFrame 생성
df = pd.DataFrame(data)

## CSV 형식 저장
df.to_csv('student_analysis.csv', encoding = 'utf-8', index=False)

# %% [markdown]
# ## 5-2 JSON 형식 저장

# %%
### 라이브러리 임포트
import json
import pandas as pd

data = {
    "이름": "홍길동",
    "나이": 25,
    "거주지": "서울",
    "관심사": ["프로그래밍", "데이터 분석", "여행"]
}

## json.dump를 이용한 저장
with open('output', mode='w', encoding='utf-8') as f:
    json.dump(data, f, indent =4, ensure_ascii=False)

## DataFrame을 이용한 저장
df=pd.DataFrame(data)
df.to_json('output_df.json', orient='records', indent=4, force_ascii=False)

# %%
# colmun 단위
## DataFrame을 이용한 저장
df=pd.DataFrame([data])
df.to_json('output_df.json', orient='columns', indent=4, force_ascii=False)

# %% [markdown]
# ## 5-3 Pandas Dataframe 데이터 추출

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터학", "경영학", "농학", "교육학", "영어영문학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}
df = pd.DataFrame(data)
df
# Out:
#     이름  학년   학점     학과    동아리
# 0  김철수   1  4.2   컴퓨터학  프로그래밍
# 1  이영희   2  3.8    경영학   독서토론
# 2  박민수   3  4.5     농학   로봇공학
# 3  최지훈   4  3.9    교육학   봉사활동
# 4  정소희   2  3.5  영어영문학   음악감상

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터학", "경영학", "농학", "교육학", "영어영문학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}
df = pd.DataFrame(data)
df

## DataFrame 인덱스 출력
#print("index:\n", df.index)
print(df.index)

## DataFrame 컬럼 출력
#print("\ncolumns:\n", df.columns)
print(df.columns)
## DataFrame 행 출력
#print("\nvalus:\n", df.values)
print(df.values.tolist())
print(df.values)

## DataFrame 값 출력
#print("\nrows:\n", df.values.tolist())
print(df.values.flatten())
# Out:
# RangeIndex(start=0, stop=5, step=1)
# Index(['이름', '학년', '학점', '학과', '동아리'], dtype='object')
# [['김철수', 1, 4.2, '컴퓨터학', '프로그래밍'], ['이영희', 2, 3.8, '경영학', '독서토론'], ['박민수', 3, 4.5, '농학', '로봇공학'], ['최지훈', 4, 3.9, '교육학', '봉사활동'], ['정소희', 2, 3.5, '영어영문학', '음악감상']]
# [['김철수' 1 4.2 '컴퓨터학' '프로그래밍']
#  ['이영희' 2 3.8 '경영학' '독서토론']
#  ['박민수' 3 4.5 '농학' '로봇공학']
#  ['최지훈' 4 3.9 '교육학' '봉사활동']
#  ['정소희' 2 3.5 '영어영문학' '음악감상']]
# ['김철수' 1 4.2 '컴퓨터학' '프로그래밍' '이영희' 2 3.8 '경영학' '독서토론' '박민수' 3 4.5 '농학'
#  '로봇공학' '최지훈' 4 3.9 '교육학' '봉사활동' '정소희' 2 3.5 '영어영문학' '음악감상']

# %% [markdown]
# ## 5-4 DataFrame 생성 방법

# %%
import pandas as pd
import json

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## 딕셔너리, csv, json으로 부터 DataFrame 생성
df1 = pd.DataFrame.from_dict(data)
df2 = pd.read_csv('students.csv')
df3 = pd.read_json('students.json')

## 세가지 방법 결과 비교
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (5, 5)
# (5, 5)
# (5, 5)

# %% [markdown]
# ## 5-5 DataFrame 저장 방법

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## Dataframe 생성
df1 = pd.DataFrame(data)

## CSV, JSON 형식으로 저장
df.to_csv('students_sores.csv')
df.to_json('students_sores.json')


## HTML 형식으로 저장
html_table = df.to_html()
with open('students_scores.html', 'w') as f:
    f.write(html_table)

# %% [markdown]
# ## 5-6 실습 시나리오

# %% [markdown]
# ## 데이터 수집

# %%
import requests

url = "http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getMinuDustFrcstDspth"
api_key = '[발급받은 인증키]'

params = {
    'serviceKey': api_key,
    'returnType': 'json',
    'numOfRows': '100',
    'pageNo': '1',
    'sidoName': '서울',
    'ver': '1.0'
}

## 데이터 수집
response = requests.get(url, params=params)

## 호출 성공/실패 출력

# %%
# 서울시 자료
import requests

url = "http://openapi.seoul.go.kr:8088/52/json/energyUseDataStatInfo/1/5/2015/01"
api_key = '152'

params = {
    'serviceKey': api_key,
    'returnType': 'json',
    'numOfRows': '100',
    'pageNo': '1',
    'sidoName': '서울',
    'ver': '1.0'
}

## 데이터 수집
response = requests.get(url, params=params)

## 호출 성공/실패 출력
print(response.json())
# Out:
# {'energyUseDataStatInfo': {'list_total_count': 2955, 'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'}, 'row': [{'YEAR': '2015', 'MON': '01', 'HOSTCODE': '광진구', 'DONGCODE': '기타', 'MM_TYPE': '기업', 'TYPE_DIV': '단체', 'TYPE_DIV_CD': 'TB_GROUP', 'CNT': '1', 'EUS': '361', 'EUS1': '322', 'EUS2': '347', 'ECO2_1_MATH_YEAR': '39', 'ECO2_2_MATH_YEAR': '16.536', 'ECO2_1_MATH': '26.5', 'ECO2_2_MATH': '11.236', 'ECO2_1': '26.5', 'ECO2_2': '11.236', 'E_TOE_YEAR': '0.00897', 'E_RATE_YEAR': '12.112', 'E_TOE_AVG': '0.006', 'E_RATE_AVG': '7.922', 'GUS': '0', 'GUS1': '0', 'GUS2': '0', 'GCO2_1_MATH_YEAR': '0', 'GCO2_2_MATH_YEAR': '0', 'GCO2_1_MATH': '0', 'GCO2_2_MATH': '0', 'GCO2_1': '0', 'GCO2_2': '0', 'G_TOE_YEAR': '0', 'G_RATE_YEAR': '0', 'G_TOE_AVG': '0', 'G_RATE_AVG': '0', 'WUS': '0', 'WUS1': '0', 'WUS2': '0', 'WCO2_1_MATH_YEAR': '0', 'WCO2_2_MATH_YEAR': '0', 'WCO2_1_MATH': '0', 'WCO2_2_MATH': '0', 'WCO2_1': '0', 'WCO2_2': '0', 'W_RATE_YEAR': '0', 'W_RATE_AVG': '0', 'HUS': '0', 'HUS1': '0', 'H
# ...

# %%
response.json()
# Out:
# {'energyUseDataStatInfo': {'list_total_count': 2955,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'YEAR': '2015',
#     'MON': '01',
#     'HOSTCODE': '광진구',
#     'DONGCODE': '기타',
#     'MM_TYPE': '기업',
#     'TYPE_DIV': '단체',
#     'TYPE_DIV_CD': 'TB_GROUP',
#     'CNT': '1',
#     'EUS': '361',
#     'EUS1': '322',
#     'EUS2': '347',
#     'ECO2_1_MATH_YEAR': '39',
#     'ECO2_2_MATH_YEAR': '16.536',
#     'ECO2_1_MATH': '26.5',
#     'ECO2_2_MATH': '11.236',
#     'ECO2_1': '26.5',
#     'ECO2_2': '11.236',
#     'E_TOE_YEAR': '0.00897',
#     'E_RATE_YEAR': '12.112',
#     'E_TOE_AVG': '0.006',
#     'E_RATE_AVG': '7.922',
#     'GUS': '0',
#     'GUS1': '0',
#     'GUS2': '0',
#     'GCO2_1_MATH_YEAR': '0',
#     'GCO2_2_MATH_YEAR': '0',
#     'GCO2_1_MATH': '0',
#     'GCO2_2_MATH': '0',
#     'GCO2_1': '0',
#     'GCO2_2': '0',
#     'G_TOE_YEAR': '0',
#     'G_RATE_YEAR': '0',
#     'G_TOE_AVG': '0',
#     'G_RATE_AVG': '0',
#     'WUS': '0',
# ...

# %% [markdown]
# ## 데이터 프레임 생성

# %%
#chatgpt

import requests
import pandas as pd

# 데이터 요청
#response = requests.get(url, params=params)
#data = response.json()

# JSON 구조에서 'row' 항목만 추출
data = response.json()
rows = data['energyUseDataStatInfo']['row']

# 원하는 컬럼만 추출
filtered_data = [
    {
        'YEAR': item['YEAR'],
        'MON': item['MON'],
        'HOSTCODE': item['HOSTCODE'],
        'EUS': item['EUS'],
        'GUS': item['GUS'],
        'WUS': item['WUS'],
        'HUS': item['HUS']
    }
    for item in rows
]

# pandas DataFrame으로 변환
df = pd.DataFrame(filtered_data)

# CSV 파일로 저장
df.to_csv('energy_use_data.csv', index=False, encoding='utf-8-sig')

print("Data saved successfully as 'energy_use_data.csv'")
# Out:
# Data saved successfully as 'energy_use_data.csv'

# %%
# 서울시
import pandas as pd

## requests로부터 response, body, item 항목 읽기
data = response.json()['YEAR']['MON']['EUS']['GUS']['WUS']['HUS']
print(type(data))
print(len(data))
print(data[0])
df =pd.DataFrame(data)
#df['pm25Grade']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2817582256.py in <cell line: 0>()
#       3
#       4 ## requests로부터 response, body, item 항목 읽기
# ----> 5 data = response.json()['YEAR']['MON']['EUS']['GUS']['WUS']['HUS']
#       6 print(type(data))
#       7 print(len(data))
#
# KeyError: 'YEAR'

# %%
# 수업 공공
import pandas as pd

## requests로부터 response, body, item 항목 읽기
data = response.json()['year']['body']['items']
print(type(data))
print(len(data))
print(data[0])
df =pd.DataFrame(data)
df.head()
df['pm25Grade']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1915030610.py in <cell line: 0>()
#       2
#       3 ## requests로부터 response, body, item 항목 읽기
# ----> 4 data = response.json()['response']['body']['items']
#       5 print(type(data))
#       6 df =pd.DataFrame(data)
#
# KeyError: 'response'

# %% [markdown]
# ## 다양항 형식으로 데이터 저장

# %%
## csv 형식 저장
df.to_csv('air_pollution.csv', index=False, encoding='utf-8')

## JSON 형식 데이터 저장
df.to_json('air_pollution.json', indent=4, force_ascii=False)

## EXCEL 형식 데이터 저장
df.to_excel('air_pollution.xlsx', index=False)

## HTML 형식 데이터 저장
df.to_html('air_pollution.html')

# %%
## 서울시
df.to_csv('air_pollution.csv', index=False, encoding='utf-8')

## JSON 형식 데이터 저장

## EXCEL 형식 데이터 저장

## HTML 형식 데이터 저장
